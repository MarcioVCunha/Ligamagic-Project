# %%
# %pip install beautifulsoup4
# %pip install selenium
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\marci\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\marci\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.2.post1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: selenium in c:\users\marci\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\marci\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\marci\anaconda3\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\marci\anaconda3\lib\site-packages (from selenium) (0.10.3)
# Requirement already satisfied: trio~=0.17 in c:\users\marci\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: sortedcontainers in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: sniffio in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: async-generator>=1.9 in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\marci\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\marci\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\marci\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\marci\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
from time import sleep

# %%
def replace_all_price(text):
    return text.replace("R$ ", "").replace(",", ".")

# %%
def get_soup(url):
    driver = webdriver.Firefox()
    driver.get(url)

    for i in range(30):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    html = driver.page_source
    driver.quit()
    soup = BeautifulSoup(html, "html.parser")

    return soup

# %%
def get_rarity(name, set_code):
    sleep(0.1)
    
    response = requests.get(f"https://api.scryfall.com/cards/named?fuzzy={name}&set={set_code}")

    data = response.json()

    return(data["rarity"])

# %%
def get_name(card):
    span = card.find("span")

    has_portuguese = str(span).find("<br/>") != -1

    if(has_portuguese):
        index = str(span).find("<br/>")
        name = str(span)[(index + 5):]
        index = name.find("</span>")
        name = name[:index]
    else:
        name = card.find('b').text

        if(name.find("(") != -1):
            index = name.find("(")
            name = name[:index]

    name = name.replace(" ", "+")

    return(name)

# %%
def get_card_infos(card, set_code, list_cards):
    name = get_name(card)
    min_price = card.find("div", class_="avgp-minprc")
    min_price = float(replace_all_price(min_price.text))
    rarity = get_rarity(name, set_code)

    if(not list_cards.count([name, min_price, rarity])):
        list_cards.append({"name": name, "min_price": min_price, "rarity": rarity, "set": set_code})

# %%
def check_set(set_code):
    response = requests.get(f"https://api.scryfall.com/sets").json()

    list_sets = response["data"]
    sets_codes = []

    for set in list_sets:
        sets_codes.append(set["code"])

    return sets_codes.count(set_code) == 0

# %%
set_code = input("Digite o código do set que deseja bustar: ")

while(check_set(set_code.lower())):
    set_code = input("Este código de set não existe, favor informar outro")

url = f"https://www.ligamagic.com.br/?view=cards/search&card=ed%3D{set_code}"
soup = get_soup(url)

list_cards_html = soup.find_all("div", class_="card-item")

if(len(list_cards_html) == 0):
    print("Nenhuma carta foi adcionada a esta coleção ainda")
else:
    list_cards = []
    for card in list_cards_html:
        get_card_infos(card, set_code, list_cards)
        print(list_cards[-1])
# Out:
# {'name': 'Faceless+One', 'min_price': 0.05, 'rarity': 'special', 'set': 'clb'}
# {'name': "Abdel+Adrian,+Gorion's+Ward", 'min_price': 0.38, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Ancient+Gold+Dragon', 'min_price': 59.84, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Archivist+of+Oghma', 'min_price': 56.82, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Ascend+from+Avernus', 'min_price': 5.9, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Astral+Confrontation', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': "Bane's+Invoker", 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Banishment', 'min_price': 0.22, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Battle+Angels+of+Tyr', 'min_price': 100.78, 'rarity': 'mythic', 'set': 'clb'}
# {'name': "Beckoning+Will-o'-Wisp", 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Blessed+Hippogriff+//+Tyr's+Blessing", 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Contraband+Livestock', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Crystal+Dragon+//+Rob+the+Hoard', 'min_price': 0.25, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Cut+a+Deal', 'min_price': 0.48, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Dawnbringer+Cleric', 'min_price': 0.2, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Ellyn+Harbreeze,+Busybody', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Far+Traveler', 'min_price': 0.23, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Flaming+Fist', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Flaming+Fist+Officer', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Githzerai+Monk', 'min_price': 0.2, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Goliath+Paladin', 'min_price': 6.75, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Greatsword+of+Tyr', 'min_price': 0.18, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Guardian+Naga+//+Banishing+Coils', 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Guiding+Bolt', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Hammers+of+Moradin', 'min_price': 0.37, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Horn+of+Valhalla+//+Ysgard's+Call", 'min_price': 1.49, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Icewind+Stalwart', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Inspiring+Leader', 'min_price': 0.2, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Lae'zel,+Vlaakith's+Champion", 'min_price': 5.4, 'rarity': 'rare', 'set': 'clb'}
# {'name': "Lae'zel's+Acrobatics", 'min_price': 2.16, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Legion+Loyalty', 'min_price': 25.11, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Lulu,+Loyal+Hollyphant', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Martial+Impetus', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Minimus+Containment', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Noble+Heritage', 'min_price': 0.4, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Pegasus+Guardian+//+Rescue+the+Foal', 'min_price': 0.2, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Rasaad+yn+Bashir', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Recruitment+Drive', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Rescuer+Chwinga', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Roving+Harper', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Scouting+Hawk', 'min_price': 0.09, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Sculpted+Sunburst', 'min_price': 1.0, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Slaughter+the+Strong', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Steadfast+Unicorn', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Stoneskin', 'min_price': 0.4, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Tabaxi+Toucaneers', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Undercellar+Sweep', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Veteran+Soldier', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'White+Plume+Adventurer', 'min_price': 22.46, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Windshaper+Planetar', 'min_price': 0.5, 'rarity': 'rare', 'set': 'clb'}
# {'name': "Wyrm's+Crossing+Patrol", 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Your+Temple+Is+Under+Attack', 'min_price': 0.15, 'rarity': 'common', 'set': 'clb'}
# {'name': "You're+Confronted+by+Robbers", 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Aarakocra+Sneak', 'min_price': 0.68, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Alora,+Merry+Thief', 'min_price': 0.33, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Ancient+Silver+Dragon', 'min_price': 99.9, 'rarity': 'mythic', 'set': 'clb'}
# {'name': "Bane's+Contingency", 'min_price': 0.24, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Blur', 'min_price': 0.14, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Candlekeep+Inspiration', 'min_price': 0.12, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Candlekeep+Sage', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Cone+of+Cold', 'min_price': 0.15, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Contact+Other+Plane', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Displacer+Kitten', 'min_price': 54.0, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Draconic+Lore', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Dragonborn+Looter', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Dream+Fracture', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Dungeon+Delver', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Elminster's+Simulacrum", 'min_price': 9.84, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Feywild+Caretaker', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Feywild+Visitor', 'min_price': 0.24, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Font+of+Magic', 'min_price': 2.44, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Gale,+Waterdeep+Prodigy', 'min_price': 0.9, 'rarity': 'rare', 'set': 'clb'}
# {'name': "Gale's+Redirection", 'min_price': 0.75, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Goggles+of+Night', 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Gray+Harbor+Merfolk', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Illithid+Harvester+//+Plant+Tadpoles', 'min_price': 0.84, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Imoen,+Mystic+Trickster', 'min_price': 0.15, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Irenicus's+Vile+Duplication", 'min_price': 5.0, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Juvenile+Mist+Dragon', 'min_price': 0.23, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Kenku+Artificer', 'min_price': 4.57, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Kindred+Discovery', 'min_price': 22.41, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Lapis+Orb+of+Dragonkind', 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Modify+Memory', 'min_price': 0.09, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Moonshae+Pixie+//+Pixie+Dust', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Mystery+Key', 'min_price': 0.18, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Nimbleclaw+Adept', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Oceanus+Dragon', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Pseudodragon+Familiar', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Psychic+Impetus', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Renari,+Merchant+of+Marvels', 'min_price': 0.25, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Robe+of+the+Archmagi', 'min_price': 2.96, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Run+Away+Together', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': "Sailors'+Bane", 'min_price': 0.15, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Sapphire+Dragon+//+Psionic+Pulse', 'min_price': 0.4, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Sea+Hag+//+Aquatic+Ingress', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Shameless+Charlatan', 'min_price': 0.19, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Stunning+Strike', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Sword+Coast+Sailor', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Sword+Coast+Serpent+//+Capsizing+Wave', 'min_price': 0.14, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Tomb+of+Horrors+Adventurer', 'min_price': 0.95, 'rarity': 'rare', 'set': 'clb'}
# {'name': "Tymora's+Invoker", 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Vhal,+Candlekeep+Researcher', 'min_price': 0.31, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Volo,+Itinerant+Scholar', 'min_price': 2.0, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Winter+Eladrin', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Wizards+of+Thay', 'min_price': 5.5, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Young+Blue+Dragon+//+Sand+Augury', 'min_price': 0.12, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Agent+of+the+Iron+Throne', 'min_price': 0.2, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Agent+of+the+Shadow+Thieves', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Altar+of+Bhaal+//+Bone+Offering', 'min_price': 1.0, 'rarity': 'rare', 'set': 'clb'}
# {'name': "Ambition's+Cost", 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Ancient+Brass+Dragon', 'min_price': 71.9, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Armor+of+Shadows', 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Arms+of+Hadar', 'min_price': 4.7, 'rarity': 'common', 'set': 'clb'}
# {'name': "Astarion's+Thirst", 'min_price': 0.5, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Atrocious+Experiment', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Blood+Money', 'min_price': 18.9, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Bonecaller+Cleric', 'min_price': 0.2, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Call+to+the+Void', 'min_price': 0.23, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Cast+Down', 'min_price': 3.0, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Chain+Devil', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Cloudkill', 'min_price': 0.18, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Criminal+Past', 'min_price': 0.4, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Cultist+of+the+Absolute', 'min_price': 0.96, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Deadly+Dispute', 'min_price': 12.49, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Elder+Brain', 'min_price': 3.36, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Eldritch+Pact', 'min_price': 0.99, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Ghastly+Death+Tyrant', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Ghost+Lantern+//+Bind+Spirit', 'min_price': 0.24, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Gray+Slaad+//+Entropic+Decay', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Guildsworn+Prowler', 'min_price': 0.14, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Hezrou+//+Demonic+Stench', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Intellect+Devourer', 'min_price': 1.2, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Mold+Folk', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Murder', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': "Myrkul's+Edict", 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': "Myrkul's+Invoker", 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Nefarious+Imp', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Nothic', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Pact+Weapon', 'min_price': 5.94, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Parasitic+Impetus', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Passageway+Seer', 'min_price': 0.12, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Ravenloft+Adventurer', 'min_price': 2.5, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Safana,+Calimport+Cutthroat', 'min_price': 0.18, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Sarevok,+Deathbringer', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Scion+of+Halaster', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Shadowheart,+Dark+Justiciar', 'min_price': 0.5, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Sigil+of+Myrkul', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Sivriss,+Nightmare+Speaker', 'min_price': 0.19, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Skullport+Merchant', 'min_price': 0.09, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Stirge', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Summon+Undead', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': "Thieves'+Tools", 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Topaz+Dragon+//+Entropic+Cloud', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Underdark+Explorer', 'min_price': 0.15, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Vicious+Battlerager', 'min_price': 1.2, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Viconia,+Drow+Apostate', 'min_price': 0.25, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Vrock', 'min_price': 0.05, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Zhentarim+Bandit', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': "Amber+Gristle+O'Maul", 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Amethyst+Dragon+//+Explosive+Crystal', 'min_price': 0.2, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Ancient+Copper+Dragon', 'min_price': 213.75, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Balor', 'min_price': 19.79, 'rarity': 'mythic', 'set': 'clb'}
# {'name': "Bhaal's+Invoker", 'min_price': 0.03, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Bloodboil+Sorcerer', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Breath+Weapon', 'min_price': 1.99, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Carnelian+Orb+of+Dragonkind', 'min_price': 0.45, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Caves+of+Chaos+Adventurer', 'min_price': 17.25, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Coronation+of+Chaos', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Descent+into+Avernus', 'min_price': 3.0, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Dragon+Cultist', 'min_price': 0.17, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Earth+Tremor', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Elturel+Survivors', 'min_price': 0.5, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Fang+Dragon+//+Forktail+Sweep', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Firbolg+Flutist', 'min_price': 0.89, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Fireball', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Ganax,+Astral+Hunter', 'min_price': 0.4, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Genasi+Enforcers', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Gnoll+War+Band', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Guild+Artisan', 'min_price': 0.35, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Gut,+True+Soul+Zealot', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Hoarding+Ogre', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Ingenious+Artillerist', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Inspired+Tinkering', 'min_price': 0.45, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Insufferable+Balladeer', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Javelin+of+Lightning', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Karlach,+Fury+of+Avernus', 'min_price': 27.95, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Lightning+Bolt', 'min_price': 7.5, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Livaan,+Cultist+of+Tiamat', 'min_price': 0.12, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Nemesis+Phoenix', 'min_price': 0.18, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Pack+Attack', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Patron+of+the+Arts', 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Popular+Entertainer', 'min_price': 0.47, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Reckless+Barbarian', 'min_price': 0.25, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Shiny+Impetus', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Stirring+Bard', 'min_price': 0.18, 'rarity': 'common', 'set': 'clb'}
# {'name': "Storm+King's+Thunder", 'min_price': 14.75, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Street+Urchin', 'min_price': 0.05, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Swashbuckler+Extraordinaire', 'min_price': 0.33, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Taunting+Kobold', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Tavern+Brawler', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Thunderwave', 'min_price': 0.09, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Tiamat's+Fanatics", 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Two-Handed+Axe', 'min_price': 1.3, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Wand+of+Wonder', 'min_price': 1.74, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Warehouse+Thief', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Wild+Magic+Surge', 'min_price': 2.87, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Wrathful+Red+Dragon', 'min_price': 16.58, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Wyll,+Blade+of+Frontiers', 'min_price': 0.47, 'rarity': 'rare', 'set': 'clb'}
# {'name': "Wyll's+Reversal", 'min_price': 1.9, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Young+Red+Dragon+//+Bathe+in+Gold', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': "You've+Been+Caught+Stealing", 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Acolyte+of+Bahamut', 'min_price': 0.42, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Ambitious+Dragonborn', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Ancient+Bronze+Dragon', 'min_price': 39.24, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Avenging+Hunter', 'min_price': 4.67, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Band+Together', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Barroom+Brawl', 'min_price': 0.7, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Bramble+Sovereign', 'min_price': 17.81, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Carefree+Swinemaster', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Circle+of+the+Land+Druid', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Cloakwood+Hermit', 'min_price': 0.19, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Cloakwood+Swarmkeeper', 'min_price': 0.17, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Colossal+Badger+//+Dig+Deep', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Draconic+Muralists', 'min_price': 0.27, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Dread+Linnorm+//+Scale+Deflection', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Druid+of+the+Emerald+Grove', 'min_price': 0.03, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Druidic+Ritual', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Earthquake+Dragon', 'min_price': 7.35, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Emerald+Dragon+//+Dissonant+Wave', 'min_price': 0.2, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Erinis,+Gloom+Stalker', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Ettercap+//+Web+Shot', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Explore+the+Underdark', 'min_price': 0.42, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Giant+Ankheg', 'min_price': 0.23, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Halsin,+Emerald+Archdruid', 'min_price': 0.15, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Hardy+Outlander', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Jade+Orb+of+Dragonkind', 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Jaheira,+Friend+of+the+Forest', 'min_price': 4.77, 'rarity': 'rare', 'set': 'clb'}
# {'name': "Jaheira's+Respite", 'min_price': 2.5, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Lurking+Green+Dragon', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Majestic+Genesis', 'min_price': 9.08, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Master+Chef', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Monster+Manual+//+Zoological+Study', 'min_price': 8.85, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Myconid+Spore+Tender', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': "Nature's+Lore", 'min_price': 3.15, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Overwhelming+Encounter', 'min_price': 0.33, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Owlbear+Cub', 'min_price': 0.98, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Owlbear+Shepherd', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Poison+the+Blade', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Predatory+Impetus', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Raised+by+Giants', 'min_price': 0.39, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Saddle+of+the+Cavalier', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Scaled+Nurturer', 'min_price': 0.16, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Sharpshooter+Elf', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Silvanus's+Invoker", 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Skanos+Dragonheart', 'min_price': 0.19, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Skullwinder', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Split+the+Spoils', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Traverse+the+Outlands', 'min_price': 6.91, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Undercellar+Myconid', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Undermountain+Adventurer', 'min_price': 14.75, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Wilson,+Refined+Grizzly', 'min_price': 0.44, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'You+Look+Upon+the+Tarrasque', 'min_price': 0.42, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'You+Meet+in+a+Tavern', 'min_price': 0.2, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Alaundo+the+Seer', 'min_price': 0.25, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Astarion,+the+Decadent', 'min_price': 0.5, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Baba+Lysaga,+Night+Witch', 'min_price': 0.36, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Bane,+Lord+of+Darkness', 'min_price': 0.36, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Bhaal,+Lord+of+Murder', 'min_price': 0.21, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Cadira,+Caller+of+the+Small', 'min_price': 0.15, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Commander+Liara+Portyr', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'The+Council+of+Four', 'min_price': 0.73, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Duke+Ulder+Ravengard', 'min_price': 0.4, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Dynaheir,+Invoker+Adept', 'min_price': 0.48, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Elminster', 'min_price': 10.99, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Gluntch,+the+Bestower', 'min_price': 0.25, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Gorion,+Wise+Mentor', 'min_price': 0.18, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Jan+Jansen,+Chaos+Crafter', 'min_price': 0.45, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Jon+Irenicus,+Shattered+One', 'min_price': 0.47, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Kagha,+Shadow+Archdruid', 'min_price': 0.2, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Korlessa,+Scale+Singer', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Lozhan,+Dragons'+Legacy", 'min_price': 0.2, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Mahadi,+Emporium+Master', 'min_price': 0.27, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Mazzy,+Truesword+Paladin', 'min_price': 0.45, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Miirym,+Sentinel+Wyrm', 'min_price': 11.95, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Minsc+&amp;+Boo,+Timeless+Heroes', 'min_price': 123.41, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Minthara,+Merciless+Soul', 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Myrkul,+Lord+of+Bones', 'min_price': 0.7, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Neera,+Wild+Mage', 'min_price': 0.5, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Nine-Fingers+Keene', 'min_price': 0.39, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Oji,+the+Exquisite+Blade', 'min_price': 0.2, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Raggadragga,+Goreguts+Boss', 'min_price': 0.25, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Raphael,+Fiendish+Savior', 'min_price': 0.9, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Rilsa+Rael,+Kingpin', 'min_price': 0.19, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Tasha,+the+Witch+Queen', 'min_price': 20.0, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Thrakkus+the+Butcher', 'min_price': 0.25, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Zevlor,+Elturel+Exile', 'min_price': 0.35, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Arcane+Encyclopedia', 'min_price': 0.05, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Arcane+Signet', 'min_price': 5.49, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Bag+of+Holding', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Basilisk+Collar', 'min_price': 7.13, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Blade+of+Selves', 'min_price': 11.7, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Bronze+Walrus', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Burnished+Hart', 'min_price': 0.15, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Campfire', 'min_price': 0.21, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Charcoal+Diamond', 'min_price': 0.2, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Chardalyn+Dragon', 'min_price': 0.09, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Cloak+of+the+Bat', 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Clockwork+Fox', 'min_price': 0.03, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Decanter+of+Endless+Water', 'min_price': 2.97, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Dire+Mimic', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Drillworks+Mole', 'min_price': 0.18, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Dungeoneer's+Pack", 'min_price': 0.14, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Fire+Diamond', 'min_price': 0.2, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Fraying+Line', 'min_price': 0.2, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Gate+Colossus', 'min_price': 0.07, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Geode+Golem', 'min_price': 0.5, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Iron+Mastiff', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Lantern+of+Revealing', 'min_price': 0.21, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Manifold+Key', 'min_price': 0.13, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Marble+Diamond', 'min_price': 0.19, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Marching+Duodrone', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Marut', 'min_price': 0.05, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Meteor+Golem', 'min_price': 0.05, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Mighty+Servant+of+Leuk-o', 'min_price': 0.5, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Mind+Stone', 'min_price': 0.75, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': 'Mirror+of+Life+Trapping', 'min_price': 0.36, 'rarity': 'rare', 'set': 'clb'}
# {'name': 'Moss+Diamond', 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Nautiloid+Ship', 'min_price': 23.16, 'rarity': 'mythic', 'set': 'clb'}
# {'name': 'Navigation+Orb', 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Nimblewright+Schematic', 'min_price': 0.1, 'rarity': 'common', 'set': 'clb'}
# {'name': "Noble's+Purse", 'min_price': 0.43, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Patriar's+Seal", 'min_price': 6.6, 'rarity': 'uncommon', 'set': 'clb'}
# {'name': "Pilgrim's+Eye", 'min_price': 0.02, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Prized+Statue', 'min_price': 0.09, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Prophetic+Prism', 'min_price': 0.04, 'rarity': 'common', 'set': 'clb'}
# {'name': 'Rug+of+Smothering', 'min_price': 0.23, 'rarity': 'uncommon', 'set': 'clb'}
