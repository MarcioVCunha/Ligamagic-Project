# %%
# %pip install beautifulsoup4
# %pip install selenium
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\marci\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\marci\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.2.post1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: selenium in c:\users\marci\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: trio~=0.17 in c:\users\marci\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\marci\anaconda3\lib\site-packages (from selenium) (1.26.14)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\marci\anaconda3\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\marci\anaconda3\lib\site-packages (from selenium) (0.10.3)
# Requirement already satisfied: sortedcontainers in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\marci\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\marci\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\marci\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\marci\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\marci\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
from time import sleep

# %%
def replace_all_price(text):
    return text.replace("R$ ", "").replace(",", ".")

# %%
def get_soup(url):
    driver = webdriver.Firefox()
    driver.get(url)

    for i in range(30):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    html = driver.page_source
    driver.quit()
    soup = BeautifulSoup(html, "html.parser")

    return soup

# %%
def get_rarity_and_type(name, set_code):
    sleep(0.1)
    
    response = requests.get(f"https://api.scryfall.com/cards/named?fuzzy={name}&set={set_code}")

    data = response.json()

    return(data["rarity"], data["type_line"])

# %%
def get_name(card):
    span = card.find("span")

    has_portuguese = str(span).find("<br/>") != -1

    if(has_portuguese):
        index = str(span).find("<br/>")
        name = str(span)[(index + 5):]
        index = name.find("</span>")
        name = name[:index]
    else:
        name = card.find('b').text

        if(name.find("(") != -1):
            index = name.find("(")
            name = name[:index]

    name = name.replace(" ", "+")

    return(name)

# %%
def get_card_infos(card, set_code, list_cards):
    name = get_name(card)
    min_price = card.find("div", class_="avgp-minprc")
    min_price = float(replace_all_price(min_price.text))
    rarity, type_line = get_rarity_and_type(name, set_code)

    if(not list_cards.count([name, min_price, rarity])):
        list_cards.append({"name": name, "min_price": min_price, "rarity": rarity, "set": set_code, "type_line": type_line})

# %%
def check_set(set_code):
    response = requests.get(f"https://api.scryfall.com/sets").json()

    list_sets = response["data"]
    sets_codes = []

    for set in list_sets:
        sets_codes.append(set["code"])

    return sets_codes.count(set_code) == 0

# %%
set_code = input("Digite o código do set que deseja bustar: ")

while(check_set(set_code.lower())):
    set_code = input("Este código de set não existe, favor informar outro")

url = f"https://www.ligamagic.com.br/?view=cards/search&card=ed%3D{set_code}"
soup = get_soup(url)

list_cards_html = soup.find_all("div", class_="card-item")

if(len(list_cards_html) == 0):
    print("Nenhuma carta foi adcionada a esta coleção ainda")
else:
    list_cards = []
    for card in list_cards_html:
        get_card_infos(card, set_code, list_cards)
        print(list_cards[-1])
# Out:
# {'name': 'Banish+from+Edoras', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'The+Battle+of+Bywater', 'min_price': 5.99, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Bill+the+Pony', 'min_price': 0.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Horse'}
# {'name': 'Boromir,+Warden+of+the+Tower', 'min_price': 40.9, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Soldier'}
# {'name': 'Dawn+of+a+New+Age', 'min_price': 59.43, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Dúnedain+Blade', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Artifact — Equipment'}
# {'name': 'Eagles+of+the+North', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Bird Soldier'}
# {'name': 'Eastfarthing+Farmer', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Halfling Peasant'}
# {'name': 'East-Mark+Cavalier', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Knight'}
# {'name': 'Éowyn,+Lady+of+Rohan', 'min_price': 0.66, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Noble'}
# {'name': 'Errand-Rider+of+Gondor', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Soldier'}
# {'name': 'Escape+from+Orthanc', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Esquire+of+the+King', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Soldier'}
# {'name': 'Faramir,+Field+Commander', 'min_price': 1.48, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Soldier'}
# {'name': 'Flowering+of+the+White+Tree', 'min_price': 28.7, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Enchantment'}
# {'name': 'Fog+on+the+Barrow-Downs', 'min_price': 0.14, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Enchantment — Aura'}
# {'name': 'Forge+Anew', 'min_price': 35.99, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': "Frodo,+Sauron's+Bane", 'min_price': 17.44, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Citizen'}
# {'name': 'Gandalf+the+White', 'min_price': 82.75, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Wizard'}
# {'name': "Hobbit's+Sting", 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Landroval,+Horizon+Witness', 'min_price': 0.1, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Bird Noble'}
# {'name': 'Lost+to+Legend', 'min_price': 0.68, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Nimble+Hobbit', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Halfling Peasant'}
# {'name': 'Now+for+Wrath,+Now+for+Ruin!', 'min_price': 0.24, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Protector+of+Gondor', 'min_price': 0.14, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Soldier'}
# {'name': 'Reprieve', 'min_price': 12.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Rosie+Cotton+of+South+Lane', 'min_price': 0.48, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Peasant'}
# {'name': 'Samwise+the+Stouthearted', 'min_price': 1.87, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Peasant'}
# {'name': 'Second+Breakfast', 'min_price': 0.14, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Shire+Shirriff', 'min_price': 0.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Halfling Soldier'}
# {'name': 'Slip+On+the+Ring', 'min_price': 0.35, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Soldier+of+the+Grey+Host', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Spirit Soldier'}
# {'name': 'Stalwarts+of+Osgiliath', 'min_price': 0.14, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Soldier'}
# {'name': 'Tale+of+Tinúviel', 'min_price': 0.59, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Enchantment — Saga'}
# {'name': 'Took+Reaper', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Halfling Peasant'}
# {'name': 'War+of+the+Last+Alliance', 'min_price': 18.73, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Enchantment — Saga'}
# {'name': 'Westfold+Rider', 'min_price': 0.25, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Knight'}
# {'name': 'You+Cannot+Pass!', 'min_price': 0.66, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': "Arwen's+Gift", 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'The+Bath+Song', 'min_price': 0.45, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Enchantment — Saga'}
# {'name': 'Bewitching+Leechcraft', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Enchantment — Aura'}
# {'name': 'Bill+Ferny,+Bree+Swindler', 'min_price': 0.66, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Rogue'}
# {'name': 'Birthday+Escape', 'min_price': 0.9, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Borne+Upon+a+Wind', 'min_price': 16.79, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Captain+of+Umbar', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Pirate'}
# {'name': "Council's+Deliberation", 'min_price': 0.7, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Deceive+the+Messenger', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Dreadful+as+the+Storm', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Elrond,+Lord+of+Rivendell', 'min_price': 0.45, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Elf Noble'}
# {'name': 'Gandalf,+Friend+of+the+Shire', 'min_price': 0.81, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Wizard'}
# {'name': 'Glorious+Gale', 'min_price': 0.25, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Goldberry,+River-Daughter', 'min_price': 5.99, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Nymph'}
# {'name': 'Grey+Havens+Navigator', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Elf Pilot'}
# {'name': 'Hithlain+Knots', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Horses+of+the+Bruinen', 'min_price': 0.65, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Ioreth+of+the+Healing+House', 'min_price': 1.6, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Cleric'}
# {'name': 'Isolation+at+Orthanc', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Ithilien+Kingfisher', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Bird'}
# {'name': 'Knights+of+Dol+Amroth', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Knight'}
# {'name': 'Lórien+Revealed', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Lost+Isle+Calling', 'min_price': 4.48, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Meneldor,+Swift+Savior', 'min_price': 0.29, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Bird Soldier'}
# {'name': 'Nimrodel+Watcher', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Elf Scout'}
# {'name': 'Pelargir+Survivor', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Peasant'}
# {'name': 'Press+the+Enemy', 'min_price': 6.93, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Rangers+of+Ithilien', 'min_price': 4.93, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Creature — Human Ranger'}
# {'name': 'Saruman+the+White', 'min_price': 0.87, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Wizard'}
# {'name': "Saruman's+Trickery", 'min_price': 0.85, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Scroll+of+Isildur', 'min_price': 6.93, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Enchantment — Saga'}
# {'name': 'Soothing+of+Sméagol', 'min_price': 0.25, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Stern+Scolding', 'min_price': 9.5, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Storm+of+Saruman', 'min_price': 35.25, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Surrounded+by+Orcs', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Treason+of+Isengard', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'The+Watcher+in+the+Water', 'min_price': 27.94, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — Kraken'}
# {'name': 'Willow-Wind', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Elemental'}
# {'name': 'Bitter+Downfall', 'min_price': 0.65, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'The+Black+Breath', 'min_price': 0.31, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Call+of+the+Ring', 'min_price': 19.9, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Cirith+Ungol+Patrol', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Orc Soldier'}
# {'name': 'Claim+the+Precious', 'min_price': 0.25, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Dunland+Crebain', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Bird Horror'}
# {'name': 'Easterling+Vanguard', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Warrior'}
# {'name': 'Gollum,+Patient+Plotter', 'min_price': 1.42, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Horror'}
# {'name': "Gollum's+Bite", 'min_price': 0.9, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Gorbag+of+Minas+Morgul', 'min_price': 1.17, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Orc Soldier'}
# {'name': 'Gothmog,+Morgul+Lieutenant', 'min_price': 0.45, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Soldier'}
# {'name': 'Gríma+Wormtongue', 'min_price': 1.8, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Advisor'}
# {'name': 'Grond,+the+Gatebreaker', 'min_price': 0.47, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Artifact — Vehicle'}
# {'name': 'Haunt+of+the+Dead+Marshes', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Nightmare Elf'}
# {'name': "Isildur's+Fateful+Strike", 'min_price': 4.75, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Instant'}
# {'name': 'Lash+of+the+Balrog', 'min_price': 0.3, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Lobelia+Sackville-Baggins', 'min_price': 11.74, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Citizen'}
# {'name': 'March+from+the+Black+Gate', 'min_price': 0.15, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Mirkwood+Bats', 'min_price': 1.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Bat'}
# {'name': 'Mordor+Muster', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Mordor+Trebuchet', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Artifact Creature — Wall'}
# {'name': 'Morgul-Knife+Wound', 'min_price': 0.24, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Enchantment — Aura'}
# {'name': 'Nasty+End', 'min_price': 0.95, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Nazgûl', 'min_price': 37.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Wraith Knight'}
# {'name': 'Oath+of+the+Grey+Host', 'min_price': 0.5, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Enchantment — Saga'}
# {'name': 'One+Ring+to+Rule+Them+All', 'min_price': 4.69, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Enchantment — Saga'}
# {'name': 'Orcish+Bowmasters', 'min_price': 156.31, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Creature — Orc Archer'}
# {'name': 'Orcish+Medicine', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': "Sam's+Desperate+Rescue", 'min_price': 0.32, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Sauron,+the+Necromancer', 'min_price': 6.99, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Horror'}
# {'name': 'Shadow+of+the+Enemy', 'min_price': 10.0, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': "Shelob's+Ambush", 'min_price': 0.3, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Snarling+Warg', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Wolf'}
# {'name': 'The+Torment+of+Gollum', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Troll+of+Khazad-dûm', 'min_price': 0.32, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Troll'}
# {'name': 'Uruk-hai+Berserker', 'min_price': 0.35, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Orc Berserker'}
# {'name': 'Voracious+Fell+Beast', 'min_price': 0.54, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Drake Beast'}
# {'name': 'Witch-King+of+Angmar', 'min_price': 61.75, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — Wraith Noble'}
# {'name': 'Battle-Scarred+Goblin', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Goblin Warrior'}
# {'name': 'Book+of+Mazarbul', 'min_price': 0.7, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Enchantment — Saga'}
# {'name': 'Breaking+of+the+Fellowship', 'min_price': 0.18, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Cast+into+the+Fire', 'min_price': 4.8, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Display+of+Power', 'min_price': 21.75, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Éomer,+Marshal+of+Rohan', 'min_price': 9.0, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Knight'}
# {'name': 'Éomer+of+the+Riddermark', 'min_price': 0.58, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Knight'}
# {'name': 'Erebor+Flamesmith', 'min_price': 0.3, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Dwarf Artificer'}
# {'name': 'Erkenbrand,+Lord+of+Westfold', 'min_price': 0.47, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Soldier'}
# {'name': 'Fall+of+Cair+Andros', 'min_price': 3.94, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Fear,+Fire,+Foes!', 'min_price': 0.5, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Fiery+Inscription', 'min_price': 1.46, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Fire+of+Orthanc', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Foray+of+Orcs', 'min_price': 0.45, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Gimli,+Counter+of+Kills', 'min_price': 0.71, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Dwarf Warrior'}
# {'name': "Gimli's+Axe", 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Artifact — Equipment'}
# {'name': "Gimli's+Fury", 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Glóin,+Dwarf+Emissary', 'min_price': 5.71, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Dwarf Advisor'}
# {'name': 'Goblin+Fireleaper', 'min_price': 0.95, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Goblin Warrior'}
# {'name': 'Grishnákh,+Brash+Instigator', 'min_price': 0.93, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Goblin Soldier'}
# {'name': 'Haradrim+Spearmaster', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Warrior'}
# {'name': 'Hew+the+Entwood', 'min_price': 19.44, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Improvised+Club', 'min_price': 0.75, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Moria+Marauder', 'min_price': 43.94, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Creature — Goblin Warrior'}
# {'name': 'Oliphaunt', 'min_price': 0.25, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Elephant'}
# {'name': 'Olog-hai+Crusher', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Troll Soldier'}
# {'name': "Quarrel's+End", 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Rally+at+the+Hornburg', 'min_price': 0.45, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': "Ranger's+Firebrand", 'min_price': 2.94, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Relentless+Rohirrim', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Knight'}
# {'name': 'Rising+of+the+Day', 'min_price': 0.85, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Rohirrim+Lancer', 'min_price': 0.25, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Knight'}
# {'name': 'Rush+the+Room', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Smite+the+Deathless', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Spiteful+Banditry', 'min_price': 72.74, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Swarming+of+Moria', 'min_price': 0.12, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'There+and+Back+Again', 'min_price': 21.98, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Enchantment — Saga'}
# {'name': 'Warbeast+of+Gorgoroth', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Beast'}
# {'name': 'Bag+End+Porter', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Dwarf'}
# {'name': "Bombadil's+Song", 'min_price': 0.6, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Brandywine+Farmer', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Halfling Peasant'}
# {'name': 'Celeborn+the+Wise', 'min_price': 0.69, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Elf Noble'}
# {'name': 'Chance-Met+Elves', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Elf Warrior'}
# {'name': 'Delighted+Halfling', 'min_price': 86.25, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Creature — Halfling Citizen'}
# {'name': 'Dúnedain+Rangers', 'min_price': 0.49, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Human Ranger'}
# {'name': 'Elven+Chorus', 'min_price': 27.93, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Elven+Farsight', 'min_price': 0.45, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Enraged+Huorn', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Treefolk'}
# {'name': 'Entish+Restoration', 'min_price': 0.95, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': "Ent's+Fury", 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Fall+of+Gil-galad', 'min_price': 7.64, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Enchantment — Saga'}
# {'name': 'Fangorn,+Tree+Shepherd', 'min_price': 4.23, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Treefolk'}
# {'name': 'Galadhrim+Bow', 'min_price': 0.14, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Artifact — Equipment'}
# {'name': 'Galadhrim+Guide', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Elf Scout'}
# {'name': 'Generous+Ent', 'min_price': 0.3, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Treefolk'}
# {'name': 'Gift+of+Strands', 'min_price': 0.5, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Enchantment — Aura'}
# {'name': 'Glorfindel,+Dauntless+Rescuer', 'min_price': 0.49, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Elf Noble'}
# {'name': 'Last+March+of+the+Ents', 'min_price': 67.42, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Legolas,+Master+Archer', 'min_price': 6.95, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Elf Archer'}
# {'name': 'Long+List+of+the+Ents', 'min_price': 0.72, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Enchantment — Saga'}
# {'name': 'Lothlórien+Lookout', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Elf Scout'}
# {'name': 'Many+Partings', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Meriadoc+Brandybuck', 'min_price': 0.73, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Citizen'}
# {'name': 'Mirkwood+Spider', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Spider'}
# {'name': 'Mirrormere+Guardian', 'min_price': 0.14, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Dwarf Soldier'}
# {'name': 'Mushroom+Watchdogs', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Dog'}
# {'name': 'Peregrin+Took', 'min_price': 0.85, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Citizen'}
# {'name': "Pippin's+Bravery", 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Quickbeam,+Upstart+Ent', 'min_price': 0.15, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Treefolk'}
# {'name': 'Radagast+the+Brown', 'min_price': 31.43, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Wizard'}
# {'name': 'Revive+the+Shire', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'The+Ring+Goes+South', 'min_price': 6.83, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Shortcut+to+Mushrooms', 'min_price': 0.49, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Enchantment'}
# {'name': 'Shower+of+Arrows', 'min_price': 0.15, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Stew+the+Coneys', 'min_price': 0.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Wose+Pathfinder', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Shaman'}
# {'name': 'Aragorn,+Company+Leader', 'min_price': 7.73, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Ranger'}
# {'name': 'Aragorn,+the+Uniter', 'min_price': 80.0, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Noble'}
# {'name': 'Arwen,+Mortal+Queen', 'min_price': 41.93, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — Elf Noble'}
# {'name': 'Arwen+Undómiel', 'min_price': 0.71, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Elf Noble'}
# {'name': "The+Balrog,+Durin's+Bane", 'min_price': 14.43, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Demon'}
# {'name': 'Bilbo,+Retired+Burglar', 'min_price': 0.7, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Rogue'}
# {'name': 'Butterbur,+Bree+Innkeeper', 'min_price': 0.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Peasant'}
# {'name': 'Denethor,+Ruling+Steward', 'min_price': 1.11, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Noble'}
# {'name': 'Doors+of+Durin', 'min_price': 26.6, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Artifact'}
# {'name': 'Elrond,+Master+of+Healing', 'min_price': 4.25, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Elf Noble'}
# {'name': 'Éowyn,+Fearless+Knight', 'min_price': 4.44, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Knight'}
# {'name': 'Faramir,+Prince+of+Ithilien', 'min_price': 5.59, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Noble'}
# {'name': 'Flame+of+Anor', 'min_price': 15.9, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Friendly+Rivalry', 'min_price': 0.47, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Frodo+Baggins', 'min_price': 0.82, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Scout'}
# {'name': 'Galadriel+of+Lothlórien', 'min_price': 8.93, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Elf Noble'}
# {'name': 'Gandalf+the+Grey', 'min_price': 6.88, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Wizard'}
# {'name': "Gandalf's+Sanction", 'min_price': 2.22, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Gimli,+Mournful+Avenger', 'min_price': 5.75, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Dwarf Warrior'}
# {'name': 'Gwaihir+the+Windlord', 'min_price': 0.71, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Bird Noble'}
# {'name': 'King+of+the+Oathbreakers', 'min_price': 12.73, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Spirit Noble'}
# {'name': 'Legolas,+Counter+of+Kills', 'min_price': 0.71, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Elf Archer'}
# {'name': 'Lotho,+Corrupt+Shirriff', 'min_price': 19.32, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Rogue'}
# {'name': 'Mauhúr,+Uruk-hai+Captain', 'min_price': 0.9, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Orc Soldier'}
# {'name': 'Merry,+Esquire+of+Rohan', 'min_price': 6.73, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Knight'}
# {'name': 'The+Mouth+of+Sauron', 'min_price': 0.15, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Advisor'}
# {'name': 'Old+Man+Willow', 'min_price': 0.31, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Treefolk'}
# {'name': 'Pippin,+Guard+of+the+Citadel', 'min_price': 13.73, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Soldier'}
# {'name': 'Prince+Imrahil+the+Fair', 'min_price': 0.84, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Noble'}
# {'name': 'Ringsight', 'min_price': 3.59, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Rise+of+the+Witch-King', 'min_price': 0.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Samwise+Gamgee', 'min_price': 13.49, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Peasant'}
# {'name': 'Saruman+of+Many+Colors', 'min_price': 71.43, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Wizard'}
# {'name': 'Sauron,+the+Dark+Lord', 'min_price': 83.0, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Horror'}
# {'name': "Sauron's+Ransom", 'min_price': 13.73, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Instant'}
# {'name': 'Shadow+Summoning', 'min_price': 0.95, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Shadowfax,+Lord+of+Horses', 'min_price': 0.15, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Horse'}
# {'name': 'Shagrat,+Loot+Bearer', 'min_price': 6.44, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Orc Soldier'}
# {'name': 'Sharkey,+Tyrant+of+the+Shire', 'min_price': 6.84, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Rogue'}
# {'name': 'Shelob,+Child+of+Ungoliant', 'min_price': 8.98, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Spider Demon'}
# {'name': 'Sméagol,+Helpful+Guide', 'min_price': 7.25, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Horror'}
# {'name': 'Strider,+Ranger+of+the+North', 'min_price': 0.59, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Ranger'}
# {'name': 'Théoden,+King+of+Rohan', 'min_price': 0.73, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Noble'}
# {'name': 'Tom+Bombadil', 'min_price': 38.94, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — God Bard'}
# {'name': 'Uglúk+of+the+White+Hand', 'min_price': 0.49, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Creature — Orc Soldier'}
# {'name': 'Andúril,+Flame+of+the+West', 'min_price': 44.9, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Artifact — Equipment'}
# {'name': 'Barrow-Blade', 'min_price': 1.42, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Artifact — Equipment'}
# {'name': 'Ent-Draught+Basin', 'min_price': 0.47, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Artifact'}
# {'name': 'Glamdring', 'min_price': 51.9, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Artifact — Equipment'}
# {'name': 'Horn+of+Gondor', 'min_price': 16.75, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Artifact'}
# {'name': 'Horn+of+the+Mark', 'min_price': 25.79, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Artifact'}
# {'name': 'Inherited+Envelope', 'min_price': 0.25, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Artifact'}
# {'name': 'Lembas', 'min_price': 5.25, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Artifact — Food'}
# {'name': 'Mirror+of+Galadriel', 'min_price': 0.97, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Artifact'}
# {'name': 'Mithril+Coat', 'min_price': 31.6, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Artifact — Equipment'}
# {'name': 'The+One+Ring', 'min_price': 314.99, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Artifact'}
# {'name': 'Palantír+of+Orthanc', 'min_price': 62.98, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Artifact'}
# {'name': 'Phial+of+Galadriel', 'min_price': 9.94, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Artifact'}
# {'name': 'Shire+Scarecrow', 'min_price': 0.1, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Artifact Creature — Scarecrow'}
# {'name': 'Sting,+the+Glinting+Dagger', 'min_price': 12.73, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Artifact — Equipment'}
# {'name': 'Stone+of+Erech', 'min_price': 3.45, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Artifact'}
# {'name': "Wizard's+Rockets", 'min_price': 0.67, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Artifact'}
# {'name': 'Barad-dûr', 'min_price': 18.74, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Land'}
# {'name': 'Great+Hall+of+the+Citadel', 'min_price': 0.45, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Land'}
# {'name': 'The+Grey+Havens', 'min_price': 2.4, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Legendary Land'}
# {'name': 'Minas+Tirith', 'min_price': 27.83, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Land'}
# {'name': 'Mines+of+Moria', 'min_price': 17.75, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Land'}
# {'name': 'Mount+Doom', 'min_price': 41.9, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Land'}
# {'name': 'Rivendell', 'min_price': 16.98, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Land'}
# {'name': 'The+Shire', 'min_price': 14.75, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Land'}
# {'name': 'Shire+Terrace', 'min_price': 1.44, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Land'}
# {'name': 'Plains+(#262)', 'min_price': 0.24, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Plains'}
# {'name': 'Plains+(#263)', 'min_price': 0.24, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Plains'}
# {'name': 'Island+(#264)', 'min_price': 0.24, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Island'}
# {'name': 'Island+(#265)', 'min_price': 0.24, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Island'}
# {'name': 'Swamp+(#266)', 'min_price': 0.24, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Swamp'}
# {'name': 'Swamp+(#267)', 'min_price': 0.24, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Swamp'}
# {'name': 'Mountain+(#268)', 'min_price': 0.24, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Mountain'}
# {'name': 'Mountain+(#269)', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Mountain'}
# {'name': 'Forest+(#270)', 'min_price': 0.24, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Forest'}
# {'name': 'Forest+(#271)', 'min_price': 0.2, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Forest'}
# {'name': 'Plains+(#272)', 'min_price': 2.02, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Plains'}
# {'name': 'Plains+(#273)', 'min_price': 2.99, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Plains'}
# {'name': 'Island+(#274)', 'min_price': 0.95, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Island'}
# {'name': 'Island+(#275)', 'min_price': 2.99, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Island'}
# {'name': 'Swamp+(#276)', 'min_price': 0.95, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Swamp'}
# {'name': 'Swamp+(#277)', 'min_price': 1.39, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Swamp'}
# {'name': 'Mountain+(#278)', 'min_price': 1.39, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Mountain'}
# {'name': 'Mountain+(#279)', 'min_price': 2.99, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Mountain'}
# {'name': 'Forest+(#280)', 'min_price': 2.95, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Forest'}
# {'name': 'Forest+(#281)', 'min_price': 2.99, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Basic Land — Forest'}
# {'name': 'Saradoc,+Master+of+Buckland', 'min_price': 10.44, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Citizen'}
# {'name': 'Elvish+Mariner', 'min_price': 7.43, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Creature — Elf Pilot'}
# {'name': 'Ringwraiths', 'min_price': 8.88, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Creature — Wraith Knight'}
# {'name': 'Assault+on+Osgiliath', 'min_price': 7.5, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Sorcery'}
# {'name': 'Elanor+Gardner', 'min_price': 18.75, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Scout'}
# {'name': 'Aragorn+and+Arwen,+Wed', 'min_price': 29.38, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — Human Elf Noble'}
# {'name': 'Sauron,+the+Lidless+Eye', 'min_price': 23.94, 'rarity': 'mythic', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Horror'}
# {'name': 'Frodo,+Determined+Hero', 'min_price': 64.94, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Warrior'}
# {'name': 'Gandalf,+White+Rider', 'min_price': 64.94, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Wizard'}
# {'name': 'Knight+of+the+Keep', 'min_price': 0.25, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Human Knight'}
# {'name': 'Gollum,+Scheming+Guide', 'min_price': 33.44, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Halfling Horror'}
# {'name': 'Witch-king,+Bringer+of+Ruin', 'min_price': 42.94, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Wraith Noble'}
# {'name': 'Fires+of+Mount+Doom', 'min_price': 13.34, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Enchantment'}
# {'name': 'Goblin+Assailant', 'min_price': 0.25, 'rarity': 'common', 'set': 'ltr', 'type_line': 'Creature — Goblin Warrior'}
# {'name': 'Galadriel,+Gift-Giver', 'min_price': 44.94, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Elf Noble'}
# {'name': 'The+Balrog,+Flame+of+Udûn', 'min_price': 15.94, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Creature — Avatar Demon'}
# {'name': "Bilbo's+Ring", 'min_price': 69.94, 'rarity': 'rare', 'set': 'ltr', 'type_line': 'Legendary Artifact — Equipment'}
# {'name': 'Nazgûl+', 'min_price': 33.24, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Wraith Knight'}
# {'name': 'Nazgûl+', 'min_price': 32.52, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Wraith Knight'}
# {'name': 'Nazgûl+', 'min_price': 37.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Wraith Knight'}
# {'name': 'Nazgûl+', 'min_price': 37.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Wraith Knight'}
# {'name': 'Nazgûl+', 'min_price': 31.67, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Wraith Knight'}
# {'name': 'Nazgûl+', 'min_price': 31.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Wraith Knight'}
# {'name': 'Nazgûl+', 'min_price': 37.25, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Wraith Knight'}
# {'name': 'Nazgûl+', 'min_price': 33.24, 'rarity': 'uncommon', 'set': 'ltr', 'type_line': 'Creature — Wraith Knight'}
